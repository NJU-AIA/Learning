# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from ddpm.data import get_loader
from ddpm.core import MyDDPM
from ddpm.train import training_loop
from ddpm.sampling import generate_new_images
from ddpm.visualize import show_images
from ddpm.models.resnet import ResNetForDDPM
from torch.optim import Adam
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

loader = get_loader(fashion=False, batch_size=128)
model = ResNetForDDPM().to(device)
ddpm = MyDDPM(model, device=device)

# %%
training_loop(ddpm, loader, n_epochs=20, optim=Adam(ddpm.parameters(), 0.001), device=device, store_path="saved_models/resnet_mnist.pt")
# Out:
# ...
# Epoch 1/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 1: 0.035 --> Best model ever (stored)
# Epoch 2/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 2: 0.033 --> Best model ever (stored)
# Epoch 3/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 3: 0.032 --> Best model ever (stored)
# Epoch 4/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 4: 0.031 --> Best model ever (stored)
# Epoch 5/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 5: 0.031 --> Best model ever (stored)
# Epoch 6/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 6: 0.030 --> Best model ever (stored)
# Epoch 7/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 7: 0.030
# Epoch 8/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 8: 0.029 --> Best model ever (stored)
# Epoch 9/20:   0%|          | 0/469 [00:00<?, ?it/s]
# Loss at epoch 9: 0.029 --> Best model ever (stored)
# Epoch 10/20:   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %%
generated = generate_new_images(ddpm, n_samples=64, device=device, gif_name="gifs/resnet_mnist.gif")
show_images(generated, "Final Results")
